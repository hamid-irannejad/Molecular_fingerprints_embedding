# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
roc_score = pd.read_csv("roc_score.csv", index_col=0)
roc_score
# Out:
#                                                mol2vec100  mol2vec300  \
# Knn , weight=uniform                             0.860817    0.871501
# Knn , weight=distance                            0.838138    0.858531
# Svm , kernel = rbf , class_weight=None           0.822925    0.829898
# Svm , kernel = linear , class_weight=None        0.775155    0.813998
# Svm , kernel = rbf , class_weight=balanced       0.851263    0.855868
# Svm , kernel = linear , class_weight=balanced    0.794800    0.812963
#
#                                                chemdist  chemberta MTR  \
# Knn , weight=uniform                           0.802567       0.866369
# Knn , weight=distance                          0.800143       0.841091
# Svm , kernel = rbf , class_weight=None         0.804777       0.838945
# Svm , kernel = linear , class_weight=None      0.696862       0.819519
# Svm , kernel = rbf , class_weight=balanced     0.818870       0.859357
# Svm , kernel = linear , class_weight=balanced  0.689472       0.816502
#
#                                                chemberta MLM  Morgan 1024  \
# Knn , weight=uniform                                0.785209     0.867814
# Knn , weight=distance                               0.779175     0.848799
# Svm , kernel = rbf , class_weight=None              0.793618     0.882763
# Svm , kernel = linear , class_weight=None           0.772228     0.876811
# Svm , kernel = rbf , class_weight=balanced          0.823209     0.899453
# Svm , kernel = linear , class_weight=balanced       0.775503     0.876138
#
#                                                Morgan 2048  count morgan 1024  \
# Knn , weight=uniform                              0.863923           0.879947
# Knn , weight=distance                             0.844871           0.861495
# Svm , kernel = rbf , class_weight=None            0.879933           0.857390
# Svm , kernel = linear , class_weight=None         0.876403           0.873256
# Svm , kernel = rbf , class_weight=balanced        0.895690           0.893021
# Svm , kernel = linear , class_weight=balanced     0.876467           0.872898
#
#                                                count morgan 2048  maccskey
# Knn , weight=uniform                                    0.873631  0.833877
# Knn , weight=distance                                   0.856126  0.781843
# Svm , kernel = rbf , class_weight=None                  0.856901  0.814196
# Svm , kernel = linear , class_weight=None               0.872690  0.798349
# Svm , kernel = rbf , class_weight=balanced              0.890174  0.843420
# Svm , kernel = linear , class_weight=balanced           0.872207  0.823936

# %%
fig = sns.heatmap(roc_score, annot=True, fmt=".2f" , center=1)
fig.figure.savefig('high_res_plot_heatmap.png', dpi=600 , bbox_inches='tight')
