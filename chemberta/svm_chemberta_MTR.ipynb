# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# %%
def roc_auc():
    return roc_auc_score(y_test, clf.predict_proba(X_test) , multi_class='ovo')

# %%
df = pd.read_csv("chemberta_idotdo_MTR.csv" , index_col=0)
df
# Out:
#             0         1         2  ...       381       382       383
# 0    0.098624  0.042223 -0.195243  ... -0.034473  0.080340  0.090633
# 1   -0.195444 -0.006335 -0.125551  ... -0.169543 -0.080592 -0.355988
# 2    0.019954  0.011441 -0.158951  ... -0.153794  0.055760  0.118594
# 3    0.208809  0.168003 -0.015691  ... -0.124051 -0.300908 -0.076737
# 4   -0.041897 -0.128232 -0.096629  ...  0.207000 -0.186747  0.126672
# ..        ...       ...       ...  ...       ...       ...       ...
# 755 -0.099143  0.104436  0.011019  ...  0.095045 -0.010944 -0.130073
# 756  0.011156  0.046114  0.019320  ...  0.237602  0.147709 -0.066069
# 757 -0.224795  0.074084 -0.111290  ... -0.198204 -0.140231 -0.261504
# 758 -0.104002  0.089321 -0.083992  ... -0.023051  0.020927 -0.080840
# 759  0.067812 -0.030397 -0.156415  ... -0.135613  0.073865  0.017983
#
# [760 rows x 384 columns]

# %%
df_class = pd.read_csv("ido_tdo.csv" , index_col=0)
df_class
# Out:
#     ido_tdo
# 0        AA
# 1        II
# 2        AI
# 3        II
# 4        II
# ..      ...
# 755      II
# 756      II
# 757      IA
# 758      AI
# 759      AA
#
# [760 rows x 1 columns]

# %%
y = df_class.iloc[:,-1]
y
# Out:
# 0      AA
# 1      II
# 2      AI
# 3      II
# 4      II
#        ..
# 755    II
# 756    II
# 757    IA
# 758    AI
# 759    AA
# Name: ido_tdo, Length: 760, dtype: object

# %%
X = df.iloc[:, :]
X
# Out:
#             0         1         2  ...       381       382       383
# 0    0.098624  0.042223 -0.195243  ... -0.034473  0.080340  0.090633
# 1   -0.195444 -0.006335 -0.125551  ... -0.169543 -0.080592 -0.355988
# 2    0.019954  0.011441 -0.158951  ... -0.153794  0.055760  0.118594
# 3    0.208809  0.168003 -0.015691  ... -0.124051 -0.300908 -0.076737
# 4   -0.041897 -0.128232 -0.096629  ...  0.207000 -0.186747  0.126672
# ..        ...       ...       ...  ...       ...       ...       ...
# 755 -0.099143  0.104436  0.011019  ...  0.095045 -0.010944 -0.130073
# 756  0.011156  0.046114  0.019320  ...  0.237602  0.147709 -0.066069
# 757 -0.224795  0.074084 -0.111290  ... -0.198204 -0.140231 -0.261504
# 758 -0.104002  0.089321 -0.083992  ... -0.023051  0.020927 -0.080840
# 759  0.067812 -0.030397 -0.156415  ... -0.135613  0.073865  0.017983
#
# [760 rows x 384 columns]

# %%
X_scaled = StandardScaler().fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled,y, stratify=y, random_state=42 , test_size=0.2)

# %%
# using default values

clf = SVC(probability=True,kernel='rbf', random_state=42)

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(probability=True, random_state=42)

# %%
ypred = clf.predict(X_test)

# %%
print("svm chemberta mtr")
print(classification_report(y_test , ypred))
print(confusion_matrix(y_test , ypred), roc_auc())
# Out:
# svm chemberta mtr
#               precision    recall  f1-score   support
#
#           AA       0.58      0.81      0.67        42
#           AI       0.86      0.71      0.77        34
#           IA       0.50      0.12      0.20        16
#           II       0.77      0.78      0.78        60
#
#     accuracy                           0.70       152
#    macro avg       0.68      0.61      0.61       152
# weighted avg       0.71      0.70      0.69       152
#
# [[34  3  1  4]
#  [ 6 24  0  4]
#  [ 8  0  2  6]
#  [11  1  1 47]] 0.8389445708839092

# %%
# using default values

clf = SVC(probability=True,kernel='linear', random_state=42)

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', probability=True, random_state=42)

# %%
ypred = clf.predict(X_test)

# %%
print("svm chemberta mtr kernel linear")
print(classification_report(y_test , ypred))
print(confusion_matrix(y_test , ypred), roc_auc())
# Out:
# svm chemberta mtr kernel linear
#               precision    recall  f1-score   support
#
#           AA       0.48      0.52      0.50        42
#           AI       0.62      0.62      0.62        34
#           IA       0.30      0.38      0.33        16
#           II       0.71      0.62      0.66        60
#
#     accuracy                           0.57       152
#    macro avg       0.53      0.53      0.53       152
# weighted avg       0.58      0.57      0.57       152
#
# [[22  9  6  5]
#  [ 7 21  1  5]
#  [ 4  1  6  5]
#  [13  3  7 37]] 0.8195193355119826

# %%
# using default values

clf = SVC(probability=True,kernel='rbf', random_state=42, class_weight='balanced')

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(class_weight='balanced', probability=True, random_state=42)

# %%
ypred = clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 ypred = clf.predict(X_test)
#
# File /run/media/rafe/volume D/Documents/new_chminformatic_project/cheminformatic_project_1_venv/lib/python3.10/site-packages/sklearn/svm/_base.py:809, in BaseSVC.predict(self, X)
#     792 def predict(self, X):
#     793     """Perform classification on samples in X.
#     794
#     795     For an one-class model, +1 or -1 is returned.
#    (...)
#     807         Class labels for samples in X.
#     808     """
# --> 809     check_is_fitted(self)
#     810     if self.break_ties and self.decision_function_shape == "ovo":
#     811         raise ValueError(
#     812             "break_ties must be False when decision_function_shape is 'ovo'"
#     813         )
#
# ...

# %%
print("svm chemberta mtr rbf balanced")
print(classification_report(y_test , ypred))
print(confusion_matrix(y_test , ypred), roc_auc())
# Out:
# svm chemberta mtr rbf balanced
#               precision    recall  f1-score   support
#
#           AA       0.53      0.67      0.59        42
#           AI       0.75      0.71      0.73        34
#           IA       0.29      0.31      0.30        16
#           II       0.80      0.67      0.73        60
#
#     accuracy                           0.64       152
#    macro avg       0.59      0.59      0.59       152
# weighted avg       0.66      0.64      0.64       152
#
# [[28  6  6  2]
#  [ 6 24  0  4]
#  [ 7  0  5  4]
#  [12  2  6 40]] 0.8593567635387488

# %%
# using default values

clf = SVC(probability=True,kernel='linear', random_state=42 , class_weight='balanced')

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(class_weight='balanced', kernel='linear', probability=True, random_state=42)

# %%
ypred = clf.predict(X_test)

# %%
print("svm chemberta mtr linear balanced")
print(classification_report(y_test , ypred))
print(confusion_matrix(y_test , ypred), roc_auc())
# Out:
# svm chemberta mtr linear balanced
#               precision    recall  f1-score   support
#
#           AA       0.59      0.57      0.58        42
#           AI       0.60      0.62      0.61        34
#           IA       0.29      0.38      0.32        16
#           II       0.75      0.68      0.71        60
#
#     accuracy                           0.61       152
#    macro avg       0.55      0.56      0.56       152
# weighted avg       0.62      0.61      0.61       152
#
# [[24 10  5  3]
#  [ 6 21  1  6]
#  [ 4  1  6  5]
#  [ 7  3  9 41]] 0.8165022953625894
