# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# heatmap for ROC_AUC score of all models
roc_score = pd.read_csv("roc_score.csv", index_col=0)
roc_score
# Out:
#                              mol2vec100  mol2vec300  chemdist  chemberta MTR  \
# Knn , weight=uniform           0.867246    0.864705  0.785036       0.869395
# Knn , weight=distance          0.844588    0.855056  0.803638       0.847374
# Svm , class_weight=None        0.834505    0.844610  0.804406       0.861823
# Svm , class_weight=balanced    0.845299    0.858321  0.784813       0.865293
#
#                              chemberta MLM  Morgan 1024  Morgan 2048  \
# Knn , weight=uniform              0.770922     0.883560     0.883828
# Knn , weight=distance             0.763470     0.868400     0.851856
# Svm , class_weight=None           0.786377     0.887628     0.889416
# Svm , class_weight=balanced       0.785024     0.894878     0.894260
#
#                              count morgan 1024  count morgan 2048  maccskey
# Knn , weight=uniform                  0.862377           0.871337  0.847513
# Knn , weight=distance                 0.863942           0.854978  0.798561
# Svm , class_weight=None               0.876886           0.874475  0.836861
# Svm , class_weight=balanced           0.888535           0.876027  0.845277

# %%
fig = sns.heatmap(roc_score, annot=True, fmt=".2f" , center=1)
fig.figure.savefig('roc_auc.png', dpi=600 , bbox_inches='tight')

# %%
# heatmap for matthews_corrcoef score of all models
matthews_corrcoef = pd.read_csv("matthews_corrcoef.csv", index_col=0)
matthews_corrcoef
# Out:
#                              mol2vec100  mol2vec300  chemdist  chemberta MTR  \
# Knn , weight=uniform           0.528042    0.549708  0.438952       0.537859
# Knn , weight=distance          0.504856    0.494962  0.473817       0.532039
# Svm , class_weight=None        0.577505    0.556563  0.462497       0.527847
# Svm , class_weight=balanced    0.515075    0.516419  0.392540       0.543268
#
#                              chemberta MLM  Morgan 1024  Morgan 2048  \
# Knn , weight=uniform              0.475377     0.532794     0.540388
# Knn , weight=distance             0.473354     0.568157     0.570441
# Svm , class_weight=None           0.517840     0.588350     0.578914
# Svm , class_weight=balanced       0.509245     0.595957     0.584897
#
#                              count morgan 1024  count morgan 2048  maccskey
# Knn , weight=uniform                  0.582095           0.617994  0.525421
# Knn , weight=distance                 0.605706           0.613190  0.504859
# Svm , class_weight=None               0.633601           0.652665  0.588888
# Svm , class_weight=balanced           0.627798           0.652665  0.554195

# %%
fig = sns.heatmap(matthews_corrcoef, annot=True, fmt=".2f" , center=0.8)
fig.figure.savefig('matthews_corrcoef.png', dpi=600 , bbox_inches='tight')

# %%
# heatmap for matthews_corrcoef score of morgan fingerprints models for external test
mcc_external_test = pd.read_csv("mcc_external_test.csv", index_col=0)
mcc_external_test
# Out:
#                                        Morgan 1024  Morgan 2048  \
# Svm , class_weight=None                   0.144373     0.349319
# Svm , class_weight=balanced               0.165096     0.286676
# Svm , class_weight=None , with SMOTE      0.259734     0.057887
# Svm , class_weight=None , with ADASYN     0.259734     0.057887
#
#                                        count morgan 1024  count morgan 2048
# Svm , class_weight=None                         0.160250           0.240473
# Svm , class_weight=balanced                     0.204689           0.271901
# Svm , class_weight=None , with SMOTE            0.124588           0.000000
# Svm , class_weight=None , with ADASYN           0.124588           0.127369

# %%
fig = sns.heatmap(mcc_external_test, annot=True, fmt=".2f" , center=0.6)
fig.figure.savefig('mcc_external_test.png', dpi=600 , bbox_inches='tight')

# %%
# heatmap for ROC_AUC score morgan fingerprints models for external test
roc_auc_external_test = pd.read_csv("roc_auc_external_test.csv", index_col=0)
roc_auc_external_test
# Out:
#                                        Morgan 1024  Morgan 2048  \
# Svm , class_weight=None                   0.674082     0.725045
# Svm , class_weight=balanced               0.699970     0.726219
# Svm , class_weight=None , with SMOTE      0.695209     0.665841
# Svm , class_weight=None , with ADASYN     0.695209     0.665841
#
#                                        count morgan 1024  count morgan 2048
# Svm , class_weight=None                         0.766573           0.782229
# Svm , class_weight=balanced                     0.773414           0.785265
# Svm , class_weight=None , with SMOTE            0.729439           0.581313
# Svm , class_weight=None , with ADASYN           0.729439           0.748369

# %%
fig = sns.heatmap(roc_auc_external_test, annot=True, fmt=".2f" , center=1)
fig.figure.savefig('roc_auc_external_test.png', dpi=600 , bbox_inches='tight')
