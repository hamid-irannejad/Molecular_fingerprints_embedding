# %%
import os
import pickle
from rdkit import Chem
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('final_total.csv')
df
# Out:
#           CHEMBLID                                       smiles  ido_ic50  \
# 0    CHEMBL1098875            O=C1c2cc(F)ccc2-n2c1nc1ccccc1c2=O      23.0
# 1    CHEMBL1209728  Cc1c(Br)oc2c1C(=O)C(=O)c1c-2ccc2c1CCCC2(C)C   10000.0
# 2    CHEMBL1276265           O=C1c2ccc(Cl)cc2-n2c1nc1ccccc1c2=O     183.0
# 3    CHEMBL1346056       Oc1ccccc1-c1nc2c3ccccc3c3ccccc3c2[nH]1   11790.0
# 4     CHEMBL139935               O=[N+]([O-])c1cc(F)c2cccnc2c1O   14610.0
# ..             ...                                          ...       ...
# 755  CHEMBL5221020     O[C@@H]1CCCC[C@H]1CNc1c(Br)ccc2[nH]ncc12    1230.0
# 756  CHEMBL5221102            Brc1cc(NC[C@H]2CCCN2)c2cn[nH]c2c1   56450.0
# 757   CHEMBL578036   CC1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(CO)coc2-1   10000.0
# 758   CHEMBL584991             Nc1nonc1/C(=N/O)Nc1ccc(F)c(Cl)c1      50.0
# 759    CHEMBL72165           O=C1c2cc(Br)ccc2-n2c1nc1ccccc1c2=O      53.9
#
#      tdo_ic50
# 0        60.0
# 1     10000.0
# 2    224200.0
# 3     12250.0
# ...

# %%
df['mol'] = df['smiles'].apply(lambda x: Chem.MolFromSmiles(x))

# %%
df
# Out:
#           CHEMBLID                                       smiles  ido_ic50  \
# 0    CHEMBL1098875            O=C1c2cc(F)ccc2-n2c1nc1ccccc1c2=O      23.0
# 1    CHEMBL1209728  Cc1c(Br)oc2c1C(=O)C(=O)c1c-2ccc2c1CCCC2(C)C   10000.0
# 2    CHEMBL1276265           O=C1c2ccc(Cl)cc2-n2c1nc1ccccc1c2=O     183.0
# 3    CHEMBL1346056       Oc1ccccc1-c1nc2c3ccccc3c3ccccc3c2[nH]1   11790.0
# 4     CHEMBL139935               O=[N+]([O-])c1cc(F)c2cccnc2c1O   14610.0
# ..             ...                                          ...       ...
# 755  CHEMBL5221020     O[C@@H]1CCCC[C@H]1CNc1c(Br)ccc2[nH]ncc12    1230.0
# 756  CHEMBL5221102            Brc1cc(NC[C@H]2CCCN2)c2cn[nH]c2c1   56450.0
# 757   CHEMBL578036   CC1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(CO)coc2-1   10000.0
# 758   CHEMBL584991             Nc1nonc1/C(=N/O)Nc1ccc(F)c(Cl)c1      50.0
# 759    CHEMBL72165           O=C1c2cc(Br)ccc2-n2c1nc1ccccc1c2=O      53.9
#
#      tdo_ic50                                               mol
# ...

# %%
from gensim.models import word2vec
from mol2vec.features import mol2alt_sentence, mol2sentence, MolSentence, DfVec, sentences2vec

# %%
w2v_model = word2vec.Word2Vec.load('./mol2vec_models/model_300dim.pkl')

# %%
def sentences2vec(sentences, model, unseen=None):

        keys = set(model.wv.key_to_index.keys())
        if unseen is None:
            unseen = np.zeros(model.vector_size, dtype=float)

        vectors = []
        for sentence in sentences:
            vec = np.sum([model.wv.get_vector(word) for word in sentence if word in keys], axis=0)
            if len(vec) == 0:
                vec = unseen
            vectors.append(vec)

        return np.array(vectors)

# %%
def generate_word_embedding(smiles_example):

        mol = Chem.MolFromSmiles(smiles_example)
        sentence = MolSentence(mol2alt_sentence(mol, radius=1))
        word_embedding = sentences2vec([sentence], w2v_model)
        result = np.array(word_embedding)

        return result

# %%
#Run this for 100 dim:
np1 = np.zeros((len(df), 100))
for i in range(df.shape[0]):
    we = generate_word_embedding(df['smiles'][i])
    np1[i, :] = we
#print(np1)

# %%
#Run this for 300 dim:
np1 = np.zeros((len(df), 300))
for i in range(df.shape[0]):
    we = generate_word_embedding(df['smiles'][i])
    np1[i, :] = we
#print(np1)

# %%
np1.shape
# Out:
# (760, 300)

# %%
pd1 = pd.DataFrame(np1)
pd1
# Out:
#           0         1         2          3         4         5          6    \
# 0    2.085246 -2.038275 -3.187863   8.277987 -1.473328  0.553464  -8.218416
# 1    2.164320 -0.599885 -3.328220   1.147567 -0.377009  1.582185  -8.842896
# 2    1.625464 -2.320905 -3.008997   8.197512 -1.164763  1.174054  -7.366459
# 3    1.899230 -2.569787 -3.410282  10.681754 -2.165567  1.730022 -11.107470
# 4    2.579365 -0.462055 -2.360175   3.983515 -2.596048  1.301527  -7.521517
# ..        ...       ...       ...        ...       ...       ...        ...
# 755  1.712499 -3.792097 -2.364244   3.363801 -0.166023 -0.001611  -8.855852
# 756  2.866019 -2.303052 -1.917922   4.422251 -0.717792 -0.029453  -7.384969
# 757  2.318216 -1.639167 -2.197451   0.764488  0.522354  0.561993  -9.767791
# 758  2.228861 -3.710076 -1.460758   3.618860  1.509769  2.148596  -7.016947
# 759  1.402920 -1.705615 -3.531063   8.404659 -0.677054  1.040710  -8.085209
#
# ...

# %%
pd1.to_csv('data_mol2vec_300.csv', index_label=False)

# %%
pd.read_csv('data_mol2vec_300.csv')
# Out:
#             0         1         2          3         4         5          6  \
# 0   -0.312471 -2.405579 -2.802194   6.104644 -3.302747  2.132782 -11.554401
# 1   -0.398744 -2.074742 -3.210000   5.372430 -3.356797  2.119695 -11.753732
# 2   -0.432436 -2.534990 -2.572980   6.523919 -3.243336  2.475069 -11.240848
# 3    0.117826 -2.385302 -2.632396   5.482557 -2.860797  3.267197 -11.957013
# 4    0.306891 -2.873120 -2.853569   5.667333 -3.257311  4.287110 -11.575791
# ..        ...       ...       ...        ...       ...       ...        ...
# 106  2.655300 -2.842201 -3.777298   6.649707 -0.178579  0.891476 -10.158477
# 107  4.134258 -3.810573 -4.563393   6.969757 -2.449172 -0.185719 -11.566064
# 108  2.662954 -3.728014 -4.641705   6.792711 -0.860587 -0.408154 -11.873514
# 109  4.112752 -4.696461 -3.869587   7.731331 -1.079638  0.460639 -12.806609
# 110  1.635059 -3.476764 -4.489965  10.008238 -0.455833 -0.239411 -13.259413
#
# ...
