# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score

# %%
df = pd.read_csv("ido&tdo_mol2vec_100.csv" , index_col=0)
df
# Out:
#             0         1         2          3          4         5         6  \
# 0   -1.453280  3.135438 -5.660918  -3.033242  -7.617049 -2.716532 -7.720714
# 1   -3.853994  6.813040 -5.372699 -10.387832  -7.475365 -7.042470 -8.528316
# 2   -1.180174  4.254755 -4.536231  -3.562603  -7.379086 -2.324686 -7.427113
# 3   -0.524230  4.466556 -6.165118  -4.102696 -10.611167 -1.818723 -5.979259
# 4   -2.448480  3.668087 -4.891652   0.175000  -3.162153 -0.902194 -5.511296
# ..        ...       ...       ...        ...        ...       ...       ...
# 755  1.039092  0.848239 -3.001012  -3.508708  -9.706405 -2.770367 -4.451425
# 756  1.353009  2.167352 -1.366708  -2.364529  -9.814615 -1.395514 -4.151305
# 757 -2.602998  7.125832 -4.669659 -10.372896  -8.373899 -5.247980 -9.301612
# 758 -2.312877 -0.113580  0.816559  -0.219393  -5.586400 -2.550617 -2.000148
# 759 -1.734595  2.714000 -6.100870  -4.617870  -6.708008 -3.416954 -7.027505
#
# ...

# %%
df_class = pd.read_csv("ido_tdo.csv" , index_col=0)
df_class
# Out:
#     ido_tdo
# 0        AA
# 1        II
# 2        AI
# 3        II
# 4        II
# ..      ...
# 755      II
# 756      II
# 757      IA
# 758      AI
# 759      AA
#
# [760 rows x 1 columns]

# %%
y = df_class.iloc[:,-1]
y
# Out:
# 0      AA
# 1      II
# 2      AI
# 3      II
# 4      II
#        ..
# 755    II
# 756    II
# 757    IA
# 758    AI
# 759    AA
# Name: ido_tdo, Length: 760, dtype: object

# %%
X = df.iloc[:, :]
X
# Out:
#             0         1         2          3          4         5         6  \
# 0   -1.453280  3.135438 -5.660918  -3.033242  -7.617049 -2.716532 -7.720714
# 1   -3.853994  6.813040 -5.372699 -10.387832  -7.475365 -7.042470 -8.528316
# 2   -1.180174  4.254755 -4.536231  -3.562603  -7.379086 -2.324686 -7.427113
# 3   -0.524230  4.466556 -6.165118  -4.102696 -10.611167 -1.818723 -5.979259
# 4   -2.448480  3.668087 -4.891652   0.175000  -3.162153 -0.902194 -5.511296
# ..        ...       ...       ...        ...        ...       ...       ...
# 755  1.039092  0.848239 -3.001012  -3.508708  -9.706405 -2.770367 -4.451425
# 756  1.353009  2.167352 -1.366708  -2.364529  -9.814615 -1.395514 -4.151305
# 757 -2.602998  7.125832 -4.669659 -10.372896  -8.373899 -5.247980 -9.301612
# 758 -2.312877 -0.113580  0.816559  -0.219393  -5.586400 -2.550617 -2.000148
# 759 -1.734595  2.714000 -6.100870  -4.617870  -6.708008 -3.416954 -7.027505
#
# ...

# %%
X_scaled = StandardScaler().fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled,y, stratify=y, random_state=42 , test_size=0.2)

# %%
clf = SVC(kernel='rbf', random_state=42 , probability=True)

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(probability=True, random_state=42)

# %%
y_pred = clf.predict(X_test)

# %%
print("mol2vec 100 svm")
print(classification_report(y_test , y_pred))
print(confusion_matrix(y_test , y_pred))
# Out:
# mol2vec 100 svm
#               precision    recall  f1-score   support
#
#           AA       0.58      0.81      0.67        42
#           AI       0.86      0.71      0.77        34
#           IA       0.75      0.19      0.30        16
#           II       0.79      0.80      0.79        60
#
#     accuracy                           0.72       152
#    macro avg       0.74      0.63      0.64       152
# weighted avg       0.74      0.72      0.70       152
#
# [[34  4  1  3]
#  [ 6 24  0  4]
#  [ 7  0  3  6]
#  [12  0  0 48]]

# %%
roc_auc_score(y_test, clf.predict_proba(X_test) , multi_class='ovo')
# Out:
# np.float64(0.8229249338624339)

# %%
def roc_auc():
    return roc_auc_score(y_test, clf.predict_proba(X_test) , multi_class='ovo')

# %%
clf = SVC(kernel='linear' , random_state=42, probability=True)

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', probability=True, random_state=42)

# %%
y_pred = clf.predict(X_test)

# %%
print("mol2vec 300 svm kernel:linear")
print(classification_report(y_test , y_pred))
print(confusion_matrix(y_test , y_pred))
# Out:
# mol2vec 300 svm kernel:linear
#               precision    recall  f1-score   support
#
#           AA       0.57      0.69      0.62        42
#           AI       0.77      0.59      0.67        34
#           IA       0.29      0.25      0.27        16
#           II       0.70      0.72      0.71        60
#
#     accuracy                           0.63       152
#    macro avg       0.58      0.56      0.57       152
# weighted avg       0.64      0.63      0.63       152
#
# [[29  6  3  4]
#  [ 4 20  0 10]
#  [ 8  0  4  4]
#  [10  0  7 43]]

# %%
roc_auc()
# Out:
# np.float64(0.7751548883442264)

# %%
clf = SVC(kernel='rbf' , probability=True , class_weight='balanced' , random_state=42)

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(class_weight='balanced', probability=True, random_state=42)

# %%
y_pred = clf.predict(X_test)

# %%
print("mol2vec 300 svm kernel:rbf class_weight = blanaced")
print(classification_report(y_test , y_pred))
print(confusion_matrix(y_test , y_pred))
roc_auc()
# Out:
# mol2vec 300 svm kernel:rbf class_weight = blanaced
#               precision    recall  f1-score   support
#
#           AA       0.58      0.69      0.63        42
#           AI       0.78      0.74      0.76        34
#           IA       0.29      0.44      0.35        16
#           II       0.83      0.63      0.72        60
#
#     accuracy                           0.65       152
#    macro avg       0.62      0.62      0.61       152
# weighted avg       0.69      0.65      0.66       152
#
# [[29  4  8  1]
#  [ 6 25  0  3]
#  [ 5  0  7  4]
#  [10  3  9 38]]
# np.float64(0.8512631788826641)

# %%
clf = SVC(kernel='linear',probability=True, class_weight='balanced' , random_state=42)

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(class_weight='balanced', kernel='linear', probability=True, random_state=42)

# %%
y_pred = clf.predict(X_test)

# %%
print("mol2vec 300 svm kernel:linear class_weight=balanced")
print(classification_report(y_test , y_pred))
print(confusion_matrix(y_test , y_pred))
roc_auc()
# Out:
# mol2vec 300 svm kernel:linear class_weight=balanced
#               precision    recall  f1-score   support
#
#           AA       0.52      0.62      0.57        42
#           AI       0.70      0.62      0.66        34
#           IA       0.29      0.50      0.36        16
#           II       0.75      0.55      0.63        60
#
#     accuracy                           0.58       152
#    macro avg       0.56      0.57      0.55       152
# weighted avg       0.63      0.58      0.59       152
#
# [[26  7  7  2]
#  [ 6 21  0  7]
#  [ 6  0  8  2]
#  [12  2 13 33]]
# np.float64(0.7948001770152504)
